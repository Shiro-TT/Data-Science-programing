# %% [markdown]
# **Họ và Tên: Đào Thanh Thiện**
#
# **MSSV: 1712782**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **ĐỌC VÀ TIỀN XỮ LÝ DỮ LIỆU**

# %%
#Đọc dữ liệu
data = pd.read_csv("Space_Corrected.csv")
df = data.copy()

# %%
#Dữ liệu gốc đặt tên cột bị dư 1 dấu cách, ta chuyển về tên đúng để dễ làm việc hơn
df.rename(columns={" Rocket": "Rocket"}, inplace = True)
df['Rocket'] = pd.to_numeric(df['Rocket'],errors='coerce')

# %%
#Ta thấy dữ liệu có 2 cột "Unnamed: 0" và "Unnamed: 0.1" có cùng số giá trị với cột số thứ tự của pandas 
#nên ta tiến hành bỏ 2 cột này, để rút gọn dữ liệu
df = df.drop(["Unnamed: 0", "Unnamed: 0.1"], axis = 1)

#Cột Rocket có nhiều dữ liệu trống, ta đặt các dữ liệu này trở về 0
df['Rocket'] = df['Rocket'].fillna(0)

#Thêm cột Country, lấy dữ liệu từ cột location
df['Country'] = df['Location'].apply(lambda x: x.strip().split(', ')[-1])

#Thêm cột Rocket Name, lấy dữ liệu từ cột Detail
df['Rocket Name'] = df['Detail'].apply(lambda x: x.strip().split(' | ')[0])
df['Program Name'] = df['Detail'].apply(lambda x: x.strip().split(' | ')[1])

#Thêm cột Year, lấy dữ liệu từ cột Datum
df['Datum'] = pd.to_datetime(df['Datum'],utc=True).dt.date
df['Year'] = pd.to_datetime(df['Datum']).dt.year
df['Month'] = pd.to_datetime(df['Datum']).dt.month

# %%
#Dữ liệu có các Location là tên khu vực không rõ ràng, ta chuyển về quốc gia đúng của nó
df['Country'] = df['Country'].replace('Shahrud Missile Test Site', 'Iran')
df['Country'] = df['Country'].replace('New Mexico', 'USA')
df['Country'] = df['Country'].replace('Pacific Missile Range Facility', 'USA')
df['Country'] = df['Country'].replace('Gran Canaria', 'USA')
df['Country'] = df['Country'].replace('Yellow Sea', 'China')
df['Country'] = df['Country'].replace('Barents Sea', 'Russia')

# %%
df.head()
# Out:
#   Company Name                                           Location       Datum  \
# 0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA  2020-08-07
# 1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...  2020-08-06
# 2       SpaceX                      Pad A, Boca Chica, Texas, USA  2020-08-04
# 3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan  2020-07-30
# 4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA  2020-07-30
#
#                                          Detail Status Rocket  Rocket  \
# 0  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky  StatusActive   50.00
# 1           Long March 2D | Gaofen-9 04 & Q-SAT  StatusActive   29.75
# 2            Starship Prototype | 150 Meter Hop  StatusActive    0.00
# 3  Proton-M/Briz-M | Ekspress-80 & Ekspress-103  StatusActive   65.00
# 4                    Atlas V 541 | Perseverance  StatusActive  145.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Datum           4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Status Rocket   4324 non-null   object
#  5   Rocket          4324 non-null   float64
#  6   Status Mission  4324 non-null   object
#  7   Country         4324 non-null   object
#  8   Rocket Name     4324 non-null   object
#  9   Program Name    4324 non-null   object
#  10  Year            4324 non-null   int64
#  11  Month           4324 non-null   int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 405.5+ KB

# %% [markdown]
# **1. Tổng các lần phóng của các công ty và quốc gia**

# %% [markdown]
# *Tổng số lần phóng của các công ty*

# %%
dataComCount = df['Company Name'].value_counts()
plt.figure(figsize=(12,8))
dataComCount.plot.bar(title='Tổng số lần phóng của các công ty')

# %% [markdown]
# *Phân bố địa điểm phóng tên lửa*

# %%
dataComCount = df['Country'].value_counts()
plt.figure(figsize=(12,8))
dataComCount.plot.bar(title='Phân bố địa điểm phóng tên lửa')

# %% [markdown]
# **2. Phân bố các lần phóng theo thời gian**

# %% [markdown]
# *Phân bố các lần phóng tên lửa của từng công ty theo năm*

# %%
df1 = df.groupby(['Year','Company Name'])['Year'].count().unstack('Company Name').fillna(0)
df1[df1.columns].plot(title='Tổng số lần phóng tên lửa của từng công ty theo từng năm',
                      kind='bar', stacked=True,figsize=(12, 8)).legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
df1 = df.groupby(['Year','Country'])['Year'].count().unstack('Country').fillna(0)
df1[df1.columns].plot(title='Tổng số lần phóng tên lửa tại từng quốc gia theo từng năm',
                      kind='bar', stacked=True,figsize=(12, 8)).legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# **3. Tỉ lệ thành công thất bại của các lần phóng**

# %%
df2 = df.groupby(['Year','Status Mission'])['Year'].count().unstack('Status Mission').fillna(0)
df2[df2.columns].plot(title='Phân bố tỉ lệ phóng thành công/thất bại của các công ty theo từng năm',
                      kind='bar', stacked=True,figsize=(12,8)).legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
labels = df['Status Rocket'].value_counts().index
colors = ['red','green']
explode = [0,0.2]
sizes = df['Status Rocket'].value_counts().values

# visual cp
plt.figure(0,figsize = (7,7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('status_rocket According to status',color = 'blue',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'status_rocket According to status')

# %% [markdown]
# **2. SỐ TIỀN MÀ CÁC CÔNG TY BỎ RA**

# %% [markdown]
# Tổng số tiền các công ty bỏ ra

# %%
dataComRoc = df[df['Rocket'] > 0]
MeanDataComRoc = dataComRoc.groupby(['Company Name'])['Rocket'].sum()
plt.figure(figsize=(12,8))
plt.title('Tổng số tiền các công ty bỏ ra',color = 'blue',fontsize = 16)
MeanDataComRoc.plot.bar()

# %% [markdown]
# Số tiền trung bình mà các công ty bỏ ra cho một lần phóng tên lửa

# %%
dataComRoc = df[df['Rocket'] > 0]
MeanDataComRoc = dataComRoc.groupby(['Company Name'])['Rocket'].mean()
plt.figure(figsize=(12,8))
plt.title('Số tiền trung bình mà các công ty bỏ ra cho một lần phóng tên lửa',color = 'blue',fontsize = 16)
MeanDataComRoc.plot.bar()

# %%
dataComRoc = df[df['Rocket'] > 0]
MeanDataComRoc = dataComRoc.groupby(['Year'])['Rocket'].sum()
plt.figure(figsize=(12,8))
plt.title('Tổng số tiền thế giới bỏ ra theo từng năm',color = 'blue',fontsize = 16)
MeanDataComRoc.plot.bar()

# %% [markdown]
# *Do dữ liệu có nhiều dòng không có dữ liệu nên ta chỉ biểu diễn các biến có dữ liệu
#
# **Vì thiếu dữ liệu nên biểu diễn trên chỉ mang tính tham khảo, tính chính xác không cao*

# %%
labels = df['Rocket Name'].value_counts().index
sizes = df['Rocket Name'].value_counts().values

# visual cp
plt.figure(0,figsize = (10,10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('status_rocket According to status',color = 'blue',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'status_rocket According to status')
